# %% [markdown]
# <a href="https://colab.research.google.com/github/SunDubey/DeepLearning/blob/main/Copy_of_Keras_Mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **The main aim of this notebook is to provide implementation of Multi layer perceptron with keras on mnist data set. These are simple dense connections implemented with keras showing improvements in accuracy in different iteration of chainging optimizer, changing activation function effect of batch normalization and dropout **

# %%
import tensorflow as tf
from tensorflow.keras import utils
from tensorflow.keras.datasets import mnist
import seaborn as sns
from tensorflow.keras.initializers import RandomNormal

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import time

def plt_dynamic(x,vy,ty,ax,colors=['b']):
  ax.plot(x,vy,'b',label="Validation Loss")
  ax.plot(x,ty,'r',label="Train Loss")
  plt.legend()
  plt.grid()
  fig.canvas.draw()

# %%
(X_train,y_train),(X_test,y_test) = mnist.load_data()

# %% [markdown]
# Reshaping our training data each image of size 28 * 28 into 784

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1]*X_train.shape[2]) 
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1]*X_test.shape[2])

# %%
X_train.shape
# Out:
# (60000, 784)

# %%
print("Number of training samples",X_train.shape[0],"and each image of shape (%d)"%(X_train.shape[1]))
print("Number of test samples",X_test.shape[0],"and each image of shape (%d)"%(X_test.shape[1]))
# Out:
# Number of training samples 60000 and each image of shape (784)
# Number of test samples 10000 and each image of shape (784)

# %%
X_train = X_train/255
X_test = X_test/255

# %%
y_train = utils.to_categorical(y_train,10)
y_test = utils.to_categorical(y_test,10)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

# %%
output_dim = 10
input_dim = X_train.shape[1]

batch_size = 128
nb_epoch = 20

# %% [markdown]
# Sequential model with a dense layer and softmax classifier at the output

# %%
model = Sequential()
model.add(Dense(output_dim,input_dim=input_dim,activation="softmax"))

# %%
model.compile(optimizer='sgd',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 469/469 [==============================] - 2s 4ms/step - loss: 1.6628 - accuracy: 0.5227 - val_loss: 0.8050 - val_accuracy: 0.8332
# Epoch 2/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7634 - accuracy: 0.8297 - val_loss: 0.6052 - val_accuracy: 0.8621
# Epoch 3/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6071 - accuracy: 0.8541 - val_loss: 0.5250 - val_accuracy: 0.8739
# Epoch 4/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5442 - accuracy: 0.8628 - val_loss: 0.4796 - val_accuracy: 0.8797
# Epoch 5/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4935 - accuracy: 0.8728 - val_loss: 0.4500 - val_accuracy: 0.8854
# Epoch 6/20
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4701 - accuracy: 0.8778 - val_loss: 0.4290 - val_accuracy: 0.8893
# Epoch 7/20
# ...

# %%
score = model.evaluate(X_test,y_test,verbose=0)
print("Test SCore",score[0])
print("Test Accuracy",score[1])

fig, axis = plt.subplots(1,1)

axis.set_xlabel("Epochs");axis.set_ylabel("Accuracy")
x = list(range(1,nb_epoch+1))
vy= history.history['val_loss']
ty = history.history['loss']
plt_dynamic(x,vy,ty,axis)
# Out:
# Test SCore 0.3352244198322296
# Test Accuracy 0.9090999960899353
# <div id='4bf2dd1b-e6be-4f40-b5eb-35f2004bb77a'></div>

# %% [markdown]
# MLP+Sigmoid+Softmax+SGD

# %% [markdown]
# Multilayer perceptron with first dense layer with sigmoid activation further dense layer with rreducing number of neurons and then sigmoid layer classifying into 10 classes[link text](https://)

# %%
model_sigmoid = Sequential()
model_sigmoid.add(Dense(512,activation="sigmoid",input_shape=(input_dim,)))
model_sigmoid.add(Dense(128,activation="sigmoid"))
model_sigmoid.add(Dense(output_dim,activation='softmax'))

model_sigmoid.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# ...
# Total params: 468,874
# Trainable params: 468,874
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_sigmoid.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

history = model_sigmoid.fit(X_train, y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 469/469 [==============================] - 5s 10ms/step - loss: 2.3112 - accuracy: 0.1706 - val_loss: 2.2187 - val_accuracy: 0.4685
# Epoch 2/20
# 469/469 [==============================] - 5s 10ms/step - loss: 2.1982 - accuracy: 0.4053 - val_loss: 2.1140 - val_accuracy: 0.5318
# Epoch 3/20
# 469/469 [==============================] - 5s 10ms/step - loss: 2.0877 - accuracy: 0.5268 - val_loss: 1.9659 - val_accuracy: 0.5820
# Epoch 4/20
# 469/469 [==============================] - 5s 10ms/step - loss: 1.9302 - accuracy: 0.5972 - val_loss: 1.7659 - val_accuracy: 0.6474
# Epoch 5/20
# 469/469 [==============================] - 4s 9ms/step - loss: 1.7241 - accuracy: 0.6573 - val_loss: 1.5334 - val_accuracy: 0.6970
# Epoch 6/20
# 469/469 [==============================] - 4s 9ms/step - loss: 1.4925 - accuracy: 0.7008 - val_loss: 1.3097 - val_accuracy: 0.7456
# Epoch 7/20
# ...

# %%
score = model_sigmoid.evaluate(X_test, y_test, verbose=0) 
print('Test score:', score[0]) 
print('Test accuracy:', score[1])

fig,ax = plt.subplots(1,1)
ax.set_xlabel('epoch') ; ax.set_ylabel('Categorical Crossentropy Loss')

# list of epoch numbers
x = list(range(1,nb_epoch+1))

# print(history.history.keys())
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# history = model_drop.fit(X_train, Y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(X_test, Y_test))

# we will get val_loss and val_acc only when you pass the paramter validation_data
# val_loss : validation loss
# val_acc : validation accuracy

# loss : training loss
# acc : train accuracy
# for each key in histrory.histrory we will have a list of length equal to number of epochs

vy = history.history['val_loss']
ty = history.history['loss']
plt_dynamic(x, vy, ty, ax)
# Out:
# Test score: 0.45716366171836853
# Test accuracy: 0.8808000087738037
# <div id='43e9f0cd-fae1-4e94-8358-82e1a567ac8e'></div>

# %%
w_after = model_sigmoid.get_weights()

h1_w = w_after[0].flatten().reshape(-1,1)
h2_w = w_after[2].flatten().reshape(-1,1)
out_w = w_after[4].flatten().reshape(-1,1)


fig = plt.figure()
plt.title("Weight matrices after model trained")
plt.subplot(1, 3, 1)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 3, 2)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')

plt.subplot(1, 3, 3)
plt.title("Trained model Weights")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()
# Out:
# <div id='0a35760d-239b-4c32-89bb-05c16d375339'></div>

# %% [markdown]
# MLP+Relu+SGD+Softmax
#
# Multilayer perceptron with first dense layer with relu activation further dense layer with reducing number of neurons and then softmax layer classifying into 10 classes with SGD optimizer

# %%
# Multilayer perceptron

# https://arxiv.org/pdf/1707.09725.pdf#page=95
# for relu layers
# If we sample weights from a normal distribution N(0,σ) we satisfy this condition with σ=√(2/(ni). 
# h1 =>  σ=√(2/(fan_in) = 0.062  => N(0,σ) = N(0,0.062)
# h2 =>  σ=√(2/(fan_in)  = 0.125  => N(0,σ) = N(0,0.125)
# out =>  σ=√(2/(fan_in+1) = 0.120  => N(0,σ) = N(0,0.120)

model_relu = Sequential()
model_relu.add(Dense(512, activation='relu', input_shape=(input_dim,), kernel_initializer=RandomNormal(mean=0.0, stddev=0.062, seed=None)))
model_relu.add(Dense(128, activation='relu', kernel_initializer=RandomNormal(mean=0.0, stddev=0.125, seed=None)) )
model_relu.add(Dense(output_dim, activation='softmax'))

model_relu.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                1290
# ...
# Total params: 468,874
# Trainable params: 468,874
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_relu.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

history = model_relu.fit(X_train, y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 469/469 [==============================] - 5s 10ms/step - loss: 1.1771 - accuracy: 0.6405 - val_loss: 0.3963 - val_accuracy: 0.8942
# Epoch 2/20
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3744 - accuracy: 0.8967 - val_loss: 0.3050 - val_accuracy: 0.9132
# Epoch 3/20
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3047 - accuracy: 0.9139 - val_loss: 0.2662 - val_accuracy: 0.9244
# Epoch 4/20
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2663 - accuracy: 0.9246 - val_loss: 0.2421 - val_accuracy: 0.9315
# Epoch 5/20
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2356 - accuracy: 0.9332 - val_loss: 0.2242 - val_accuracy: 0.9368
# Epoch 6/20
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2146 - accuracy: 0.9398 - val_loss: 0.2076 - val_accuracy: 0.9407
# Epoch 7/20
# ...

# %%
score = model_relu.evaluate(X_test, y_test, verbose=0) 
print('Test score:', score[0]) 
print('Test accuracy:', score[1])

fig,ax = plt.subplots(1,1)
ax.set_xlabel('epoch') ; ax.set_ylabel('Categorical Crossentropy Loss')

# list of epoch numbers
x = list(range(1,nb_epoch+1))

# print(history.history.keys())
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# history = model_drop.fit(X_train, Y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(X_test, Y_test))

# we will get val_loss and val_acc only when you pass the paramter validation_data
# val_loss : validation loss
# val_acc : validation accuracy

# loss : training loss
# acc : train accuracy
# for each key in histrory.histrory we will have a list of length equal to number of epochs

vy = history.history['val_loss']
ty = history.history['loss']
plt_dynamic(x, vy, ty, ax)
# Out:
# Test score: 0.12524528801441193
# Test accuracy: 0.9616000056266785
# <div id='118b8b28-7f6b-469a-b630-fdc0f041240b'></div>

# %%
w_after = model_relu.get_weights()

h1_w = w_after[0].flatten().reshape(-1,1)
h2_w = w_after[2].flatten().reshape(-1,1)
out_w = w_after[4].flatten().reshape(-1,1)


fig = plt.figure()
plt.title("Weight matrices after model trained")
plt.subplot(1, 3, 1)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 3, 2)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')

plt.subplot(1, 3, 3)
plt.title("Trained model Weights")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()
# Out:
# <div id='fc23a875-5334-4b0d-aec8-86535f13d937'></div>

# %% [markdown]
# MLP+Relu+Adam+Softmax
#
# Multilayer perceptron with first dense layer with Relu activation further dense layer with reducing number of neurons and then softmax layer classifying into 10 classes with Adam optimizer

# %%
model_relu = Sequential()
model_relu.add(Dense(512, activation='relu', input_shape=(input_dim,), kernel_initializer=RandomNormal(mean=0.0, stddev=0.062, seed=None)))
model_relu.add(Dense(128, activation='relu', kernel_initializer=RandomNormal(mean=0.0, stddev=0.125, seed=None)) )
model_relu.add(Dense(output_dim, activation='softmax'))

print(model_relu.summary())

model_relu.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model_relu.fit(X_train, y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(X_test, y_test))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_7 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                1290
# ...
# Total params: 468,874
# Trainable params: 468,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.4336 - accuracy: 0.8681 - val_loss: 0.1066 - val_accuracy: 0.9662
# Epoch 2/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0876 - accuracy: 0.9743 - val_loss: 0.0847 - val_accuracy: 0.9741
# Epoch 3/20
# ...

# %%
score = model_relu.evaluate(X_test, y_test, verbose=0) 
print('Test score:', score[0]) 
print('Test accuracy:', score[1])

fig,ax = plt.subplots(1,1)
ax.set_xlabel('epoch') ; ax.set_ylabel('Categorical Crossentropy Loss')

# list of epoch numbers
x = list(range(1,nb_epoch+1))

# print(history.history.keys())
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# history = model_drop.fit(X_train, Y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(X_test, Y_test))

# we will get val_loss and val_acc only when you pass the paramter validation_data
# val_loss : validation loss
# val_acc : validation accuracy

# loss : training loss
# acc : train accuracy
# for each key in histrory.histrory we will have a list of length equal to number of epochs


vy = history.history['val_loss']
ty = history.history['loss']
plt_dynamic(x, vy, ty, ax)
# Out:
# Test score: 0.10951916873455048
# Test accuracy: 0.9797999858856201
# <div id='f0fd9dfc-4390-438e-b318-e1ba4ee95161'></div>

# %%
w_after = model_relu.get_weights()

h1_w = w_after[0].flatten().reshape(-1,1)
h2_w = w_after[2].flatten().reshape(-1,1)
out_w = w_after[4].flatten().reshape(-1,1)


fig = plt.figure()
plt.title("Weight matrices after model trained")
plt.subplot(1, 3, 1)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 3, 2)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')

plt.subplot(1, 3, 3)
plt.title("Trained model Weights")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()
# Out:
# <div id='b1f318c3-a49b-4c4e-8f76-a4345f0e8966'></div>

# %% [markdown]
# <h2> MLP + Batch-Norm on hidden Layers + AdamOptimizer </2>

# %% [markdown]
# **Gives Accuracy of 97.24**

# %%
pip install "tensorflow==1.14.0"

# %%
from tensorflow.keras.layers import BatchNormalization

model_batch = Sequential()

model_batch.add(Dense(512, activation='sigmoid', input_shape=(input_dim,), kernel_initializer=RandomNormal(mean=0.0, stddev=0.039, seed=None)))
model_batch.add(BatchNormalization())

model_batch.add(Dense(128, activation='sigmoid', kernel_initializer=RandomNormal(mean=0.0, stddev=0.55, seed=None)) )
model_batch.add(BatchNormalization())

model_batch.add(Dense(output_dim, activation='softmax'))


model_batch.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 512)               401920
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               65664
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                1290
# ...
# Total params: 471,434
# Trainable params: 470,154
# Non-trainable params: 1,280
# _________________________________________________________________

# %%
model_batch.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model_batch.fit(X_train, y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(X_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.2995 - acc: 0.9119 - val_loss: 0.2060 - val_acc: 0.9423
# Epoch 2/20
# 60000/60000 [==============================] - 6s 95us/sample - loss: 0.1761 - acc: 0.9483 - val_loss: 0.1782 - val_acc: 0.9487
# Epoch 3/20
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.1384 - acc: 0.9593 - val_loss: 0.1524 - val_acc: 0.9558
# Epoch 4/20
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.1146 - acc: 0.9652 - val_loss: 0.1404 - val_acc: 0.9599
# Epoch 5/20
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.0994 - acc: 0.9694 - val_loss: 0.1297 - val_acc: 0.9626
# Epoch 6/20
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.0820 - acc: 0.9752 - val_loss: 0.1199 - val_acc: 0.9652
# Epoch 7/20
# ...

# %%
score = model_batch.evaluate(X_test, y_test, verbose=0) 
print('Test score:', score[0]) 
print('Test accuracy:', score[1])

fig,ax = plt.subplots(1,1)
ax.set_xlabel('epoch') ; ax.set_ylabel('Categorical Crossentropy Loss')

# list of epoch numbers
x = list(range(1,nb_epoch+1))

# print(history.history.keys())
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# history = model_drop.fit(X_train, Y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(X_test, Y_test))

# we will get val_loss and val_acc only when you pass the paramter validation_data
# val_loss : validation loss
# val_acc : validation accuracy

# loss : training loss
# acc : train accuracy
# for each key in histrory.histrory we will have a list of length equal to number of epochs

vy = history.history['val_loss']
ty = history.history['loss']
plt_dynamic(x, vy, ty, ax)
# Out:
# Test score: 0.1099923058872344
# Test accuracy: 0.9724
# <div id='ed1db51f-65fa-408f-b3fd-8d49ea043a05'></div>

# %%
w_after = model_batch.get_weights()

h1_w = w_after[0].flatten().reshape(-1,1)
h2_w = w_after[2].flatten().reshape(-1,1)
out_w = w_after[4].flatten().reshape(-1,1)


fig = plt.figure()
plt.title("Weight matrices after model trained")
plt.subplot(1, 3, 1)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 3, 2)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')

plt.subplot(1, 3, 3)
plt.title("Trained model Weights")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()
# Out:
# <div id='4d88f831-8503-4dbb-aa0d-0fa99ddcee57'></div>

# %% [markdown]
# <h2> 5. MLP + Dropout + AdamOptimizer </h2>

# %% [markdown]
# **Gives Accuracy of 96.62**

# %%
# https://stackoverflow.com/questions/34716454/where-do-i-call-the-batchnormalization-function-in-keras

from tensorflow.keras.layers import Dropout

model_drop = Sequential()

model_drop.add(Dense(512, activation='sigmoid', input_shape=(input_dim,), kernel_initializer=RandomNormal(mean=0.0, stddev=0.039, seed=None)))
model_drop.add(BatchNormalization())
model_drop.add(Dropout(0.5))

model_drop.add(Dense(128, activation='sigmoid', kernel_initializer=RandomNormal(mean=0.0, stddev=0.55, seed=None)) )
model_drop.add(BatchNormalization())
model_drop.add(Dropout(0.5))

model_drop.add(Dense(output_dim, activation='softmax'))


model_drop.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_6 (Dense)              (None, 512)               401920
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               65664
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                1290
# ...

# %%
model_drop.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model_drop.fit(X_train, y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(X_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 7s 120us/sample - loss: 0.6665 - acc: 0.7943 - val_loss: 0.2911 - val_acc: 0.9172
# Epoch 2/20
# 60000/60000 [==============================] - 7s 113us/sample - loss: 0.4305 - acc: 0.8696 - val_loss: 0.2521 - val_acc: 0.9252
# Epoch 3/20
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.3843 - acc: 0.8838 - val_loss: 0.2332 - val_acc: 0.9324
# Epoch 4/20
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.3584 - acc: 0.8914 - val_loss: 0.2239 - val_acc: 0.9322
# Epoch 5/20
# 60000/60000 [==============================] - 7s 112us/sample - loss: 0.3395 - acc: 0.8976 - val_loss: 0.2142 - val_acc: 0.9363
# Epoch 6/20
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.3216 - acc: 0.9037 - val_loss: 0.2023 - val_acc: 0.9413
# Epoch 7/20
# ...

# %%
score = model_drop.evaluate(X_test, y_test, verbose=0) 
print('Test score:', score[0]) 
print('Test accuracy:', score[1])

fig,ax = plt.subplots(1,1)
ax.set_xlabel('epoch') ; ax.set_ylabel('Categorical Crossentropy Loss')

# list of epoch numbers
x = list(range(1,nb_epoch+1))

# print(history.history.keys())
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# history = model_drop.fit(X_train, Y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(X_test, Y_test))

# we will get val_loss and val_acc only when you pass the paramter validation_data
# val_loss : validation loss
# val_acc : validation accuracy

# loss : training loss
# acc : train accuracy
# for each key in histrory.histrory we will have a list of length equal to number of epochs

vy = history.history['val_loss']
ty = history.history['loss']
plt_dynamic(x, vy, ty, ax)
# Out:
# Test score: 0.1075799967829138
# Test accuracy: 0.9662
# <div id='60976757-02b3-4f45-881d-6526ac2184f2'></div>

# %%
w_after = model_drop.get_weights()

h1_w = w_after[0].flatten().reshape(-1,1)
h2_w = w_after[2].flatten().reshape(-1,1)
out_w = w_after[4].flatten().reshape(-1,1)


fig = plt.figure()
plt.title("Weight matrices after model trained")
plt.subplot(1, 3, 1)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 3, 2)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')

plt.subplot(1, 3, 3)
plt.title("Trained model Weights")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()
# Out:
# <div id='80f58ff5-de81-4691-851d-832ba304ac16'></div>
